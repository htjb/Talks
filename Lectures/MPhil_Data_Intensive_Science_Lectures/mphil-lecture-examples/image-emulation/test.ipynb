# %% [markdown]
# ## CNNs for image emulation
#
# The code illustrates how to use CNNs for image emulation. The emulator learns to generate images of correlated gaussian distributions. It is a very trivial toy example but shows the kind of thing that might be used for 21-cm tomography and power spectra estimation in the future.  An example application of CNNs to learn the 2D 21-cm power spectrum can be found in https://arxiv.org/abs/2309.05697.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import tqdm

# %% [markdown]
# ### Training and test data
#
# We first have to generate some images to train on. One can imagine this being a set of images from a complex semi-numerical simulation of the 21-cm signal. Here I am generating samples from a 2D Gaussian distribution with random means and covariances, histogramming the samples and effectively assigning the bin height to the pixel intensity. I have 16 bins in my histogram which corresponds to a (16 x 16) pixel image. The means and covariances of my multivariate gaussian are saved as the inputs to my network. In a real example the inputs might be cosmological describing the star formation rate of early galaxies or the expansion rate of the Universe.
#
# I split the dataset into training and test examples for validation.
#
# Typically CNNs perform quite well without any kind of normalisation to the input data and target images although this can of course be done.

# %%
def generator(params):
    signal = np.random.multivariate_normal([params[0], params[1]],
                [[params[2], params[3]],[params[4], params[2]]], 1000)
    return signal

def prior(n):
    theta = np.zeros((n, 5))
    theta[:, 0] = np.random.uniform(-1, 1, n) # mean 1
    theta[:, 1] = np.random.uniform(-1, 1, n) # mean 2
    theta[:, 2] = np.random.uniform(0, 0.5, n) # standard deviation
    theta[:, 3] = np.random.uniform(0, 0.5, n) # cov1
    theta[:, 4] = np.random.uniform(0, 0.5, n) # cov2
    return theta

samples = prior(10000)
signals = []
for i in tqdm(range(len(samples))):
    signal = generator(samples[i])
    H, xedges, yedges = np.histogram2d(signal[:, 0], signal[:, 1], 
                range=[[-3, 3], [-3, 3]], bins=16)
    signals.append(H)
signals = np.array(signals)

from sklearn.model_selection import train_test_split

train_data, test_data, train_labels, test_labels = train_test_split(samples, signals, 
                        test_size=0.2, random_state=42)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /var/folders/pk/s11gmpgj1_d0jt1ykgfx7rt80000gn/T/ipykernel_1676/2206126262.py:2: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   signal = np.random.multivariate_normal([params[0], params[1]],
# 100%|██████████| 10000/10000 [00:01<00:00, 6536.58it/s]

# %% [markdown]
# ### Building the networks
#
# Next I define two different neural networks to emulate the multivariate gaussian images I generated earlier. The first uses convolutional layers to build up complexity in the image where as the latter just uses dense layers and reshapes the ouput of the final layer into a (16 x16) image. The idea is to demonstrate how powerful the convolutional layers are.
#
# I train the networks with early stopping and use a pixel by pixel absolute error loss function between the network output and the example training data.

# %%
def loss(y_true, y_pred):
    #print(y_pred)
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    return tf.reduce_mean(tf.math.abs(y_true -y_pred))

model_cnn = tf.keras.models.Sequential([
  # dense layers from parameters to pixels
  tf.keras.layers.Dense(3, activation='tanh'),
  tf.keras.layers.Dense(10, activation='tanh'),
  tf.keras.layers.Dense(32, activation='tanh'),
  tf.keras.layers.Dense(32, activation='tanh'),
  tf.keras.layers.Dense(64, activation='tanh'),
  tf.keras.layers.Dense(256, activation='tanh'),
  # reshape into 16 by 16 array or image
  tf.keras.layers.Reshape((16, 16, 1)),
  # upsample it using some interpolation to 32 by 32
  tf.keras.layers.UpSampling2D((2, 2), interpolation='bicubic'),
  # expand it into a cube with layers
  tf.keras.layers.Conv2D(3, (2, 2)),
  # convolve it back down to an image for pixel by pixel loss
  tf.keras.layers.Conv2D(2, (16, 16)),
  tf.keras.layers.Conv2D(1, (1, 1))
])

model_no_cnn = tf.keras.models.Sequential([
  # dense layers from parameters to pixels
  tf.keras.layers.Dense(3, activation='tanh'),
  tf.keras.layers.Dense(10, activation='tanh'),
  tf.keras.layers.Dense(32, activation='tanh'),
  tf.keras.layers.Dense(32, activation='tanh'),
  tf.keras.layers.Dense(64, activation='tanh'),
  tf.keras.layers.Dense(256, activation='tanh'),
  # reshape into 16 by 16 array or image
  tf.keras.layers.Reshape((16, 16, 1))
])

# building the model with the adam optimizer and mean squared error loss function
model_cnn.compile(optimizer='adam',
              loss=loss,)

# building the model with the adam optimizer and mean squared error loss function
model_no_cnn.compile(optimizer='adam',
              loss=loss,)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# training the model
model_cnn.fit(samples, signals, epochs=500, batch_size=250,
          callbacks=[callback], validation_data=(test_data, test_labels))

# training the model
model_no_cnn.fit(samples, signals, epochs=500, batch_size=250,
          callbacks=[callback], validation_data=(test_data, test_labels))
# Out:
# Epoch 1/500
# 40/40 [==============================] - 2s 32ms/step - loss: 3.8952 - val_loss: 3.8077
# Epoch 2/500
# 40/40 [==============================] - 1s 34ms/step - loss: 3.5549 - val_loss: 3.3651
# Epoch 3/500
# 40/40 [==============================] - 1s 32ms/step - loss: 3.2668 - val_loss: 3.1478
# Epoch 4/500
# 40/40 [==============================] - 1s 30ms/step - loss: 3.0685 - val_loss: 2.9589
# Epoch 5/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.9004 - val_loss: 2.8005
# Epoch 6/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.7569 - val_loss: 2.6768
# Epoch 7/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.6520 - val_loss: 2.5908
# Epoch 8/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.5781 - val_loss: 2.5251
# Epoch 9/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.5196 - val_loss: 2.4706
# Epoch 10/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.4708 - val_loss: 2.4265
# Epoch 11/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.4295 - val_loss: 2.3864
# Epoch 12/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.3877 - val_loss: 2.3450
# Epoch 13/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.3503 - val_loss: 2.3099
# Epoch 14/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.3161 - val_loss: 2.2796
# Epoch 15/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.2866 - val_loss: 2.2531
# Epoch 16/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.2598 - val_loss: 2.2278
# Epoch 17/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.2353 - val_loss: 2.2041
# Epoch 18/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.2157 - val_loss: 2.1903
# Epoch 19/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.2022 - val_loss: 2.1719
# Epoch 20/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.1838 - val_loss: 2.1527
# Epoch 21/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.1699 - val_loss: 2.1467
# Epoch 22/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.1585 - val_loss: 2.1429
# Epoch 23/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.1508 - val_loss: 2.1304
# Epoch 24/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.1373 - val_loss: 2.1088
# Epoch 25/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.1282 - val_loss: 2.1035
# Epoch 26/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.1215 - val_loss: 2.0884
# Epoch 27/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.1117 - val_loss: 2.0823
# Epoch 28/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.1012 - val_loss: 2.0797
# Epoch 29/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.0971 - val_loss: 2.0721
# Epoch 30/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0909 - val_loss: 2.0674
# Epoch 31/500
# 40/40 [==============================] - 1s 30ms/step - loss: 2.0857 - val_loss: 2.0603
# Epoch 32/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0787 - val_loss: 2.0540
# Epoch 33/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0786 - val_loss: 2.0601
# Epoch 34/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0708 - val_loss: 2.0479
# Epoch 35/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0662 - val_loss: 2.0412
# Epoch 36/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0649 - val_loss: 2.0409
# Epoch 37/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0552 - val_loss: 2.0284
# Epoch 38/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0533 - val_loss: 2.0264
# Epoch 39/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0488 - val_loss: 2.0248
# Epoch 40/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0466 - val_loss: 2.0234
# Epoch 41/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0439 - val_loss: 2.0262
# Epoch 42/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0396 - val_loss: 2.0176
# Epoch 43/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0359 - val_loss: 2.0076
# Epoch 44/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0342 - val_loss: 2.0137
# Epoch 45/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0333 - val_loss: 2.0097
# Epoch 46/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0274 - val_loss: 2.0055
# Epoch 47/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0278 - val_loss: 2.0118
# Epoch 48/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0240 - val_loss: 2.0037
# Epoch 49/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0212 - val_loss: 2.0001
# Epoch 50/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0222 - val_loss: 2.0068
# Epoch 51/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0172 - val_loss: 1.9970
# Epoch 52/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0146 - val_loss: 1.9931
# Epoch 53/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0126 - val_loss: 1.9916
# Epoch 54/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0134 - val_loss: 1.9985
# Epoch 55/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0107 - val_loss: 1.9903
# Epoch 56/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0075 - val_loss: 1.9848
# Epoch 57/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0030 - val_loss: 1.9875
# Epoch 58/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0060 - val_loss: 1.9904
# Epoch 59/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0022 - val_loss: 1.9836
# Epoch 60/500
# 40/40 [==============================] - 1s 31ms/step - loss: 2.0012 - val_loss: 1.9877
# Epoch 61/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9980 - val_loss: 1.9756
# Epoch 62/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9994 - val_loss: 1.9796
# Epoch 63/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9930 - val_loss: 1.9740
# Epoch 64/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9910 - val_loss: 1.9773
# Epoch 65/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9928 - val_loss: 1.9687
# Epoch 66/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9868 - val_loss: 1.9706
# Epoch 67/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9868 - val_loss: 1.9630
# Epoch 68/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9835 - val_loss: 1.9622
# Epoch 69/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9845 - val_loss: 1.9625
# Epoch 70/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9863 - val_loss: 1.9686
# Epoch 71/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9804 - val_loss: 1.9606
# Epoch 72/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9808 - val_loss: 1.9638
# Epoch 73/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9800 - val_loss: 1.9599
# Epoch 74/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9741 - val_loss: 1.9522
# Epoch 75/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9762 - val_loss: 1.9615
# Epoch 76/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9760 - val_loss: 1.9545
# Epoch 77/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9739 - val_loss: 1.9582
# Epoch 78/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9697 - val_loss: 1.9530
# Epoch 79/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9687 - val_loss: 1.9469
# Epoch 80/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9684 - val_loss: 1.9436
# Epoch 81/500
# 40/40 [==============================] - 1s 32ms/step - loss: 1.9645 - val_loss: 1.9461
# Epoch 82/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9627 - val_loss: 1.9500
# Epoch 83/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9642 - val_loss: 1.9479
# Epoch 84/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9642 - val_loss: 1.9537
# Epoch 85/500
# 40/40 [==============================] - 1s 31ms/step - loss: 1.9633 - val_loss: 1.9456
# Epoch 1/500
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9108 - val_loss: 3.8915
# Epoch 2/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8620 - val_loss: 3.8390
# Epoch 3/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8354 - val_loss: 3.8308
# Epoch 4/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8306 - val_loss: 3.8274
# Epoch 5/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8277 - val_loss: 3.8250
# Epoch 6/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8253 - val_loss: 3.8226
# Epoch 7/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8231 - val_loss: 3.8204
# Epoch 8/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8210 - val_loss: 3.8184
# Epoch 9/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8190 - val_loss: 3.8166
# Epoch 10/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8175 - val_loss: 3.8152
# Epoch 11/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8162 - val_loss: 3.8141
# Epoch 12/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8153 - val_loss: 3.8133
# Epoch 13/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8147 - val_loss: 3.8128
# Epoch 14/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8143 - val_loss: 3.8124
# Epoch 15/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8139 - val_loss: 3.8120
# Epoch 16/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8136 - val_loss: 3.8118
# Epoch 17/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8133 - val_loss: 3.8115
# Epoch 18/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8130 - val_loss: 3.8113
# Epoch 19/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8128 - val_loss: 3.8111
# Epoch 20/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8127 - val_loss: 3.8109
# Epoch 21/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8125 - val_loss: 3.8108
# Epoch 22/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8125 - val_loss: 3.8106
# Epoch 23/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8122 - val_loss: 3.8104
# Epoch 24/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8121 - val_loss: 3.8104
# Epoch 25/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8120 - val_loss: 3.8102
# Epoch 26/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8120 - val_loss: 3.8104
# Epoch 27/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8118 - val_loss: 3.8100
# Epoch 28/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8117 - val_loss: 3.8100
# Epoch 29/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8117 - val_loss: 3.8099
# Epoch 30/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8115 - val_loss: 3.8098
# Epoch 31/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8114 - val_loss: 3.8097
# Epoch 32/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8114 - val_loss: 3.8097
# Epoch 33/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8112 - val_loss: 3.8096
# Epoch 34/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8112 - val_loss: 3.8094
# Epoch 35/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8110 - val_loss: 3.8092
# Epoch 36/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8109 - val_loss: 3.8092
# Epoch 37/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8108 - val_loss: 3.8090
# Epoch 38/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8107 - val_loss: 3.8089
# Epoch 39/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8106 - val_loss: 3.8089
# Epoch 40/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8105 - val_loss: 3.8087
# Epoch 41/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8103 - val_loss: 3.8087
# Epoch 42/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8102 - val_loss: 3.8085
# Epoch 43/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8102 - val_loss: 3.8086
# Epoch 44/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8101 - val_loss: 3.8083
# Epoch 45/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8099 - val_loss: 3.8083
# Epoch 46/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8099 - val_loss: 3.8080
# Epoch 47/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8097 - val_loss: 3.8080
# Epoch 48/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8095 - val_loss: 3.8079
# Epoch 49/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8094 - val_loss: 3.8078
# Epoch 50/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8093 - val_loss: 3.8078
# Epoch 51/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8093 - val_loss: 3.8076
# Epoch 52/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8092 - val_loss: 3.8076
# Epoch 53/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8091 - val_loss: 3.8074
# Epoch 54/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8090 - val_loss: 3.8075
# Epoch 55/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8090 - val_loss: 3.8073
# Epoch 56/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8089 - val_loss: 3.8072
# Epoch 57/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8088 - val_loss: 3.8071
# Epoch 58/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8088 - val_loss: 3.8071
# Epoch 59/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8088 - val_loss: 3.8071
# Epoch 60/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8087 - val_loss: 3.8071
# Epoch 61/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8086 - val_loss: 3.8071
# Epoch 62/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8086 - val_loss: 3.8068
# Epoch 63/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8086 - val_loss: 3.8068
# Epoch 64/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8085 - val_loss: 3.8069
# Epoch 65/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8084 - val_loss: 3.8067
# Epoch 66/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8085 - val_loss: 3.8068
# Epoch 67/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8083 - val_loss: 3.8068
# Epoch 68/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8082 - val_loss: 3.8066
# Epoch 69/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8082 - val_loss: 3.8067
# Epoch 70/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8082 - val_loss: 3.8066
# Epoch 71/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8081 - val_loss: 3.8066
# Epoch 72/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8082 - val_loss: 3.8065
# Epoch 73/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8080 - val_loss: 3.8064
# Epoch 74/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8080 - val_loss: 3.8063
# Epoch 75/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8079 - val_loss: 3.8063
# Epoch 76/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8078 - val_loss: 3.8062
# Epoch 77/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8078 - val_loss: 3.8061
# Epoch 78/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8078 - val_loss: 3.8060
# Epoch 79/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8078 - val_loss: 3.8061
# Epoch 80/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8076 - val_loss: 3.8061
# Epoch 81/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8077 - val_loss: 3.8060
# Epoch 82/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8076 - val_loss: 3.8060
# Epoch 83/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8075 - val_loss: 3.8058
# Epoch 84/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8075 - val_loss: 3.8060
# Epoch 85/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8074 - val_loss: 3.8059
# Epoch 86/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8074 - val_loss: 3.8058
# Epoch 87/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8073 - val_loss: 3.8058
# Epoch 88/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8074 - val_loss: 3.8056
# Epoch 89/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8073 - val_loss: 3.8058
# Epoch 90/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8074 - val_loss: 3.8056
# Epoch 91/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8072 - val_loss: 3.8055
# Epoch 92/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8071 - val_loss: 3.8054
# Epoch 93/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8073 - val_loss: 3.8058
# Epoch 94/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8071 - val_loss: 3.8054
# Epoch 95/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8072 - val_loss: 3.8055
# Epoch 96/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8070 - val_loss: 3.8052
# Epoch 97/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8069 - val_loss: 3.8052
# Epoch 98/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8068 - val_loss: 3.8051
# Epoch 99/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8067 - val_loss: 3.8052
# Epoch 100/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8068 - val_loss: 3.8051
# Epoch 101/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8067 - val_loss: 3.8051
# Epoch 102/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8067 - val_loss: 3.8051
# Epoch 103/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8066 - val_loss: 3.8050
# Epoch 104/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8067 - val_loss: 3.8050
# Epoch 105/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8068 - val_loss: 3.8051
# Epoch 106/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8066 - val_loss: 3.8050
# Epoch 107/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8065 - val_loss: 3.8049
# Epoch 108/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8065 - val_loss: 3.8050
# Epoch 109/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8065 - val_loss: 3.8052
# Epoch 110/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8065 - val_loss: 3.8048
# Epoch 111/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8063 - val_loss: 3.8047
# Epoch 112/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8063 - val_loss: 3.8047
# Epoch 113/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8063 - val_loss: 3.8047
# Epoch 114/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8063 - val_loss: 3.8047
# Epoch 115/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8062 - val_loss: 3.8046
# Epoch 116/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8062 - val_loss: 3.8046
# Epoch 117/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8061 - val_loss: 3.8046
# Epoch 118/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8061 - val_loss: 3.8046
# Epoch 119/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8061 - val_loss: 3.8046
# Epoch 120/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8060 - val_loss: 3.8045
# Epoch 121/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8060 - val_loss: 3.8044
# Epoch 122/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8060 - val_loss: 3.8044
# Epoch 123/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8059 - val_loss: 3.8043
# Epoch 124/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8059 - val_loss: 3.8043
# Epoch 125/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8059 - val_loss: 3.8042
# Epoch 126/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8058 - val_loss: 3.8042
# Epoch 127/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8058 - val_loss: 3.8041
# Epoch 128/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8057 - val_loss: 3.8040
# Epoch 129/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8057 - val_loss: 3.8040
# Epoch 130/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8056 - val_loss: 3.8040
# Epoch 131/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8056 - val_loss: 3.8039
# Epoch 132/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8056 - val_loss: 3.8038
# Epoch 133/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8054 - val_loss: 3.8039
# Epoch 134/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8055 - val_loss: 3.8038
# Epoch 135/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8054 - val_loss: 3.8039
# Epoch 136/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8053 - val_loss: 3.8037
# Epoch 137/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8052 - val_loss: 3.8036
# Epoch 138/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8052 - val_loss: 3.8036
# Epoch 139/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8052 - val_loss: 3.8035
# Epoch 140/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8050 - val_loss: 3.8033
# Epoch 141/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8048 - val_loss: 3.8033
# Epoch 142/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8048 - val_loss: 3.8032
# Epoch 143/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8046 - val_loss: 3.8033
# Epoch 144/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8047 - val_loss: 3.8029
# Epoch 145/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8044 - val_loss: 3.8027
# Epoch 146/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8041 - val_loss: 3.8025
# Epoch 147/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8039 - val_loss: 3.8022
# Epoch 148/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8036 - val_loss: 3.8023
# Epoch 149/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8034 - val_loss: 3.8016
# Epoch 150/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8031 - val_loss: 3.8015
# Epoch 151/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8028 - val_loss: 3.8012
# Epoch 152/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8025 - val_loss: 3.8010
# Epoch 153/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8023 - val_loss: 3.8007
# Epoch 154/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8020 - val_loss: 3.8003
# Epoch 155/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8017 - val_loss: 3.8001
# Epoch 156/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8016 - val_loss: 3.7999
# Epoch 157/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8014 - val_loss: 3.7997
# Epoch 158/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8012 - val_loss: 3.7995
# Epoch 159/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8010 - val_loss: 3.7994
# Epoch 160/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8008 - val_loss: 3.7992
# Epoch 161/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8007 - val_loss: 3.7990
# Epoch 162/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8005 - val_loss: 3.7988
# Epoch 163/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8002 - val_loss: 3.7986
# Epoch 164/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8001 - val_loss: 3.7985
# Epoch 165/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8000 - val_loss: 3.7984
# Epoch 166/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7999 - val_loss: 3.7983
# Epoch 167/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7998 - val_loss: 3.7983
# Epoch 168/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7996 - val_loss: 3.7980
# Epoch 169/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7995 - val_loss: 3.7979
# Epoch 170/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7994 - val_loss: 3.7979
# Epoch 171/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7993 - val_loss: 3.7979
# Epoch 172/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7993 - val_loss: 3.7976
# Epoch 173/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7990 - val_loss: 3.7975
# Epoch 174/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7989 - val_loss: 3.7974
# Epoch 175/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7989 - val_loss: 3.7973
# Epoch 176/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7987 - val_loss: 3.7973
# Epoch 177/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7987 - val_loss: 3.7970
# Epoch 178/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7985 - val_loss: 3.7969
# Epoch 179/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7985 - val_loss: 3.7969
# Epoch 180/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7984 - val_loss: 3.7969
# Epoch 181/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7983 - val_loss: 3.7966
# Epoch 182/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7982 - val_loss: 3.7966
# Epoch 183/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7982 - val_loss: 3.7966
# Epoch 184/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7981 - val_loss: 3.7965
# Epoch 185/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7979 - val_loss: 3.7964
# Epoch 186/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7978 - val_loss: 3.7961
# Epoch 187/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7975 - val_loss: 3.7959
# Epoch 188/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7974 - val_loss: 3.7961
# Epoch 189/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7973 - val_loss: 3.7956
# Epoch 190/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7971 - val_loss: 3.7956
# Epoch 191/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7971 - val_loss: 3.7955
# Epoch 192/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7970 - val_loss: 3.7957
# Epoch 193/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7969 - val_loss: 3.7954
# Epoch 194/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7968 - val_loss: 3.7952
# Epoch 195/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7966 - val_loss: 3.7951
# Epoch 196/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7966 - val_loss: 3.7950
# Epoch 197/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7965 - val_loss: 3.7949
# Epoch 198/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7963 - val_loss: 3.7948
# Epoch 199/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7963 - val_loss: 3.7948
# Epoch 200/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7962 - val_loss: 3.7948
# Epoch 201/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7962 - val_loss: 3.7947
# Epoch 202/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7962 - val_loss: 3.7946
# Epoch 203/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7962 - val_loss: 3.7950
# Epoch 204/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7963 - val_loss: 3.7945
# Epoch 205/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7960 - val_loss: 3.7943
# Epoch 206/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7958 - val_loss: 3.7943
# Epoch 207/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7957 - val_loss: 3.7941
# Epoch 208/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7956 - val_loss: 3.7941
# Epoch 209/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7956 - val_loss: 3.7941
# Epoch 210/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7956 - val_loss: 3.7943
# Epoch 211/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7956 - val_loss: 3.7940
# Epoch 212/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7954 - val_loss: 3.7940
# Epoch 213/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7954 - val_loss: 3.7939
# Epoch 214/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7953 - val_loss: 3.7940
# Epoch 215/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7953 - val_loss: 3.7939
# Epoch 216/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7954 - val_loss: 3.7938
# Epoch 217/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7952 - val_loss: 3.7937
# Epoch 218/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7951 - val_loss: 3.7937
# Epoch 219/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7952 - val_loss: 3.7937
# Epoch 220/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7951 - val_loss: 3.7937
# Epoch 221/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7950 - val_loss: 3.7935
# Epoch 222/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7950 - val_loss: 3.7935
# Epoch 223/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7949 - val_loss: 3.7934
# Epoch 224/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7950 - val_loss: 3.7935
# Epoch 225/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7949 - val_loss: 3.7933
# Epoch 226/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7948 - val_loss: 3.7933
# Epoch 227/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7949 - val_loss: 3.7935
# Epoch 228/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7947 - val_loss: 3.7934
# Epoch 229/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7947 - val_loss: 3.7932
# Epoch 230/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7946 - val_loss: 3.7933
# Epoch 231/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7946 - val_loss: 3.7931
# Epoch 232/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7947 - val_loss: 3.7933
# Epoch 233/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7945 - val_loss: 3.7930
# Epoch 234/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7945 - val_loss: 3.7931
# Epoch 235/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7945 - val_loss: 3.7930
# Epoch 236/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7945 - val_loss: 3.7931
# Epoch 237/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7944 - val_loss: 3.7929
# Epoch 238/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7930
# Epoch 239/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7929
# Epoch 240/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7929
# Epoch 241/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7931
# Epoch 242/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7928
# Epoch 243/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7942 - val_loss: 3.7928
# Epoch 244/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7941 - val_loss: 3.7928
# Epoch 245/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7943 - val_loss: 3.7929
# Epoch 246/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7941 - val_loss: 3.7926
# Epoch 247/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7940 - val_loss: 3.7926
# Epoch 248/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7940 - val_loss: 3.7925
# Epoch 249/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7939 - val_loss: 3.7925
# Epoch 250/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7940 - val_loss: 3.7926
# Epoch 251/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7939 - val_loss: 3.7924
# Epoch 252/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7938 - val_loss: 3.7924
# Epoch 253/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7938 - val_loss: 3.7923
# Epoch 254/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7938 - val_loss: 3.7926
# Epoch 255/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7937 - val_loss: 3.7924
# Epoch 256/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7937 - val_loss: 3.7924
# Epoch 257/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7937 - val_loss: 3.7923
# Epoch 258/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7936 - val_loss: 3.7922
# Epoch 259/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7936 - val_loss: 3.7922
# Epoch 260/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7935 - val_loss: 3.7920
# Epoch 261/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7935 - val_loss: 3.7921
# Epoch 262/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7934 - val_loss: 3.7920
# Epoch 263/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7934 - val_loss: 3.7920
# Epoch 264/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7934 - val_loss: 3.7920
# Epoch 265/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7933 - val_loss: 3.7920
# Epoch 266/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7933 - val_loss: 3.7920
# Epoch 267/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7933 - val_loss: 3.7919
# Epoch 268/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7933 - val_loss: 3.7920
# Epoch 269/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7933 - val_loss: 3.7918
# Epoch 270/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7932 - val_loss: 3.7920
# Epoch 271/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7932 - val_loss: 3.7919
# Epoch 272/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7931 - val_loss: 3.7921
# Epoch 273/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7932 - val_loss: 3.7917
# Epoch 274/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7931 - val_loss: 3.7916
# Epoch 275/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7931 - val_loss: 3.7916
# Epoch 276/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7930 - val_loss: 3.7916
# Epoch 277/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7931 - val_loss: 3.7917
# Epoch 278/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7917
# Epoch 279/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7930 - val_loss: 3.7915
# Epoch 280/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7916
# Epoch 281/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7930 - val_loss: 3.7916
# Epoch 282/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7916
# Epoch 283/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7914
# Epoch 284/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7915
# Epoch 285/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7930 - val_loss: 3.7915
# Epoch 286/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7929 - val_loss: 3.7914
# Epoch 287/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7928 - val_loss: 3.7916
# Epoch 288/500
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7928 - val_loss: 3.7915

# %%
def error(true, pred):
    return np.mean(np.abs(true - pred)/np.max(true)*100)

pred_cnn = []
pred_no_cnn = []
loss_cnn = []
loss_no_cnn = []
for i in tqdm(range(len(test_data))):
    pred_cnn.append(model_cnn.predict(test_data[i].reshape(1, -1), verbose=0).reshape(16, 16))
    pred_no_cnn.append(model_no_cnn.predict(test_data[i].reshape(1, -1), verbose=0).reshape(16, 16))
    loss_cnn.append(error(test_labels[i], pred_cnn[i]))
    loss_no_cnn.append(error(test_labels[i], pred_no_cnn[i]))

print('Mean CNN Loss: ', np.mean(loss_cnn))
print('Mean No CNN Loss: ', np.mean(loss_no_cnn))

fig, axes = plt.subplots(1, 3)
axes[0].imshow(pred_cnn[10])
axes[1].imshow(test_labels[10])
axes[2].imshow(pred_no_cnn[10])
for i in range(3):
    axes[i].axis('off')
axes[0].set_title('Truth')
axes[1].set_title('CNN\nLoss = {:.2f}'.format(loss_cnn[10]))
axes[2].set_title('Dense Layers\nOnly\nLoss = {:.2f}'.format(loss_no_cnn[10]))
plt.savefig('Example-cnn.png', dpi=300, bbox_inches='tight')
# Out:
# 100%|██████████| 2000/2000 [01:06<00:00, 30.22it/s]
# Mean CNN Loss:  0.019771309954066715
# Mean No CNN Loss:  0.044503638365442785
